# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",200)

# %%
df=pd.read_csv("PBL5recommendationdata.csv",encoding="iso-8859-1")
# Out:
# C:\Users\mehme\AppData\Local\Temp\ipykernel_16960\2712350104.py:1: DtypeWarning: Columns (20,33,73,106,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("PBL5recommendationdata.csv",encoding="iso-8859-1")

# %% [markdown]
# ## EDA

# %%
df
# Out:
#       Customers.id Customers.fname Customers.lname Customers.company  \
# 0              797         Christy            Dill          Company0
# 1                3            John           Smith          Company1
# 2                3            John           Smith          Company1
# 3                4           James        Anderson               NaN
# 4                5         Abraham          Pollak          Company3
# ...            ...             ...             ...               ...
# 4189          3730            Nora         Fontana               NaN
# 4190          3732        Kennithe          Tecora               NaN
# 4191          3733           Tinna         Randall               NaN
# 4192          3735         HALIMAH          SHAHID               NaN
# 4193          3736         Michael         Kiernan               NaN
#
#       Customers.create_date  Customers.status  Customers.mailing  \
# 0                1426018724               NaN                NaN
# ...

# %%
df.isnull().sum().sort_values(ascending=False) #We examine the empty lines.
# Out:
# Products.freight_cost       4194
# Orders.mailing              4194
# Orders.gift_message         4194
# Orders.registry_id          4194
# Products.right_flag         4194
#                             ...
# Order_Items.parent             0
# Order_Items.product_name       0
# Order_Items.qty                0
# Order_Items.price              0
# Customers.id                   0
# Length: 181, dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
a=list()
for i in range(181):
    if len(df[df.columns[i]].value_counts())<(4194/2):
        a.append(df.columns[i])
df.drop(a,axis=1, inplace=True)
#We delete columns that are more than half empty.

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Orders.payment_code        748
# Orders.payment_id          430
# Orders.shipped_date        346
# Orders.updated_date         23
# Orders.payment_date         18
# Orders.payment_amount       18
# Customers.lname              0
# Order_Items.id               0
# Orders.placed_date           0
# Customers.id                 0
# Orders.total                 0
# Orders.order_number          0
# Orders.lname                 0
# Orders.customer_id           0
# Orders.id                    0
# Customers.last_modified      0
# Customers.create_date        0
# Order_Items.parent           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4194 entries, 0 to 4193
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customers.id             4194 non-null   int64
#  1   Customers.lname          4194 non-null   object
#  2   Customers.create_date    4194 non-null   int64
#  3   Customers.last_modified  4194 non-null   int64
#  4   Orders.id                4194 non-null   int64
#  5   Orders.customer_id       4194 non-null   int64
#  6   Orders.lname             4194 non-null   object
#  7   Orders.order_number      4194 non-null   object
#  8   Orders.total             4194 non-null   float64
#  9   Orders.payment_date      4176 non-null   float64
#  10  Orders.payment_amount    4176 non-null   float64
#  11  Orders.payment_id        3764 non-null   object
#  12  Orders.payment_code      3446 non-null   object
#  13  Orders.placed_date       4194 non-null   int64
# ...

# %%
df["Orders.payment_amount"].value_counts()
# Out:
# 129.99    39
# 16.23     27
# 132.99    23
# 22.66     20
# 14.85     19
#           ..
# 54.60      1
# 107.46     1
# 95.42      1
# 184.10     1
# 24.54      1
# Name: Orders.payment_amount, Length: 2253, dtype: int64

# %%
df.drop(["Orders.payment_code","Orders.payment_id","Orders.shipped_date","Orders.updated_date","Orders.payment_date"],axis=1, inplace=True)
#We delete some columns.

# %%
df
# Out:
#       Customers.id Customers.lname  Customers.create_date  \
# 0              797            Dill             1426018724
# 1                3           Smith             1386089139
# 2                3           Smith             1386089139
# 3                4        Anderson             1386780263
# 4                5          Pollak             1386861599
# ...            ...             ...                    ...
# 4189          3730         Fontana             1463408698
# 4190          3732          Tecora             1463412756
# 4191          3733         Randall             1463413245
# 4192          3735          SHAHID             1463416687
# 4193          3736         Kiernan             1463418049
#
#       Customers.last_modified  Orders.id  Orders.customer_id Orders.lname  \
# 0                  1437764306       3758                 797         Dill
# 1                  1437764354         23                   3        Smith
# ...

# %%
df.drop(["Order_Items.parent","Orders.payment_amount","Orders.order_number"],axis=1, inplace=True)

# %%
df.corr() #We look at their correlations.
# Out:
#                          Customers.id  Customers.create_date  \
# Customers.id                 1.000000               0.951397
# Customers.create_date        0.951397               1.000000
# Customers.last_modified      0.891923               0.883490
# Orders.id                    0.931931               0.891490
# Orders.customer_id           1.000000               0.951397
# Orders.total                -0.037907              -0.016653
# Orders.placed_date           0.885630               0.936910
# Order_Items.id               0.931643               0.896279
#
#                          Customers.last_modified  Orders.id  \
# Customers.id                            0.891923   0.931931
# Customers.create_date                   0.883490   0.891490
# Customers.last_modified                 1.000000   0.831338
# Orders.id                               0.831338   1.000000
# Orders.customer_id                      0.891923   0.931931
# ...

# %%
df
# Out:
#       Customers.id Customers.lname  Customers.create_date  \
# 0              797            Dill             1426018724
# 1                3           Smith             1386089139
# 2                3           Smith             1386089139
# 3                4        Anderson             1386780263
# 4                5          Pollak             1386861599
# ...            ...             ...                    ...
# 4189          3730         Fontana             1463408698
# 4190          3732          Tecora             1463412756
# 4191          3733         Randall             1463413245
# 4192          3735          SHAHID             1463416687
# 4193          3736         Kiernan             1463418049
#
#       Customers.last_modified  Orders.id  Orders.customer_id Orders.lname  \
# 0                  1437764306       3758                 797         Dill
# 1                  1437764354         23                   3        Smith
# ...

# %%
df.to_csv("PBL5recommendationdata(düzenlenmiş).csv")
